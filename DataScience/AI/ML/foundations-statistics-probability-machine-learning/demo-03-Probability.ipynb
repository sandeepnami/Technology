# %% [markdown]
# #### Import Libraries

# %%
import random
import numpy as np

import scipy.stats

import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="darkgrid")

# %% [markdown]
# #### Small Samples

# %%
def flip(n):

    result = []

    for i in range(1, n + 1):
        result.append(random.choice(["Heads", "Tails"]))

    return result

# %% [markdown]
# ### TODO Recording
#
# Please make sure you get different counts for heads and tails when you run this cell below

# %%
result = flip(10)

result
# Out:
# ['Tails',
#  'Heads',
#  'Heads',
#  'Tails',
#  'Tails',
#  'Tails',
#  'Tails',
#  'Tails',
#  'Tails',
#  'Heads']

# %%
plt.figure(figsize=(12, 8))

sns.countplot(x=result)

plt.xlabel('Coin Flip')
plt.title('Counts')

plt.show()

# %%
result = flip(100)

plt.figure(figsize=(12, 8))

sns.countplot(x=result)

plt.xlabel('Coin Flip')
plt.title('Counts')

plt.show()

# %%
result = flip(100000)

plt.figure(figsize=(12, 8))

sns.countplot(x=result)

plt.xlabel('Coin Flip')
plt.title('Counts')

plt.show()

# %%
def roll(n):
    
    result = []

    for i in range(1, n + 1):
        result.append(random.choice([1, 2, 3, 4, 5, 6]))
        
    return result

# %%
result = roll(10)

result
# Out:
# [1, 2, 6, 5, 2, 1, 5, 1, 6, 2]

# %%
plt.figure(figsize=(12, 8))

sns.countplot(x=result)

plt.xlabel('Dice Roll')
plt.title('Counts')

plt.show()

# %%
result = roll(100)

plt.figure(figsize=(12, 8))

sns.countplot(x=result)

plt.xlabel('Dice Roll')
plt.title('Counts')

plt.show()

# %%
result = roll(100000)

plt.figure(figsize=(12, 8))

sns.countplot(x=result)

plt.xlabel('Dice Roll')
plt.title('Counts')

plt.show()
