# %%
import requests
import re

from bs4 import BeautifulSoup

# %% [markdown]
# #### This url is having information about how to build a static websites

# %%
url = "https://mashable.com/2014/08/28/static-website-generators/"

resp = requests.get(url)

# %%
soup = BeautifulSoup(resp.text, 'lxml')

soup
# Out:
# <!DOCTYPE html>
# <html data-env="production" lang="en" xml:lang="en">
# <head>
# <script>
#   window.__o = {"channel":"Tech","content_type":"article","top_channel":"Tech","content_source_type":"Internal","content_source_name":"Internal","author_name":"Grace Smith","age":"1827","pub_day":28,"pub_month":8,"pub_year":2014,"pub_date":"08/28/2014","sourced_from":"Internal","isPostView":true,"post_lead_type":"Default","topics":"apps-software,dev-design,node.js,python,ruby,static-website,tech,uncategorized,website-creation","campaign":null,"display_mode":"list","viral_video_type":null,"standalone_video_show":null,"mash_video_show":null,"b_flag":true,"cms_author_name":null,"cms_author_geo":"us","cms_author_team":null,"bp_id":null,"shoppable":null};
#   window.dataLayer = window.dataLayer || [];
#   window.dataLayer.push(window.__o);
#   window._geo = "IN";
#   window.__domStart = (new Date().getTime())
#   window.optimizely = [["setCookieExpiration", 180]];
#   !function(){var n;return n={},window.getExperimentValue=function(e,t,u){var r,i;return i=n[e]&&null!=n[e][t]&&n[e][t]||u,null!=(r="function"==typeof i?i():void 0)?r:i},window.setExperimentValue=function(e,t,u){return n[e]||(n[e]={}),n[e][t]=u}}();
#   var adonis = adonis || {};
#   adonis.conditionalAdRendering = true;
#   adonis.transport = 'https://www.adiode.com/http';
#   adonis.scriptResources = ['c.amazon-adsystem.com/aax2/', 'js-sec.indexww.com/ht/'];
# </script>
# <title>13 Static Site Generators to Help You Build Your Ultimate Website</title>
# <link href="https://a.amz.mshcdn.com/assets/app-aa9e2819d9ee8b5b94ae6795fa28af98c57ab83d542ee99b54975db7e9055eda.css" media="screen" rel="stylesheet"/>
# <link href="https://a.amz.mshcdn.com/assets/csshake-08f0628738d4674eeeeec2337d9c0c85450194c2de5747e07c21371e25a54c18.css" media="screen" rel="stylesheet"/>
# <link href="https://a.amz.mshcdn.com/assets/posts-cf2686c4a4777816be86f958f31179b7356b3d72ec7f061e4785b5e5f4466f07.css" media="all" rel="stylesheet"/>
# <link href="http://feeds.mashable.com/Mashable" rel="alternate" title="Mashable" type="application/rss+xml"/>
# <link href="https://mashable.com/apple-touch-icon-57x57.png?v=m2Pmw8zNwl" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://mashable.com/apple-touch-icon-60x60.png?v=m2Pmw8zNwl" rel="apple-touch-icon" sizes="60x60"/>
# <link href="https://mashable.com/apple-touch-icon-72x72.png?v=m2Pmw8zNwl" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://mashable.com/apple-touch-icon-76x76.png?v=m2Pmw8zNwl" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://mashable.com/apple-touch-icon-114x114.png?v=m2Pmw8zNwl" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://mashable.com/apple-touch-icon-120x120.png?v=m2Pmw8zNwl" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://mashable.com/apple-touch-icon-144x144.png?v=m2Pmw8zNwl" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://mashable.com/apple-touch-icon-152x152.png?v=m2Pmw8zNwl" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://mashable.com/apple-touch-icon-180x180.png?v=m2Pmw8zNwl" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://mashable.com/favicon-32x32.png?v=m2Pmw8zNwl" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://mashable.com/android-chrome-192x192.png?v=m2Pmw8zNwl" rel="icon" sizes="192x192" type="image/png"/>
# <link href="https://mashable.com/favicon-96x96.png?v=m2Pmw8zNwl" rel="icon" sizes="96x96" type="image/png"/>
# <link href="https://mashable.com/favicon-16x16.png?v=m2Pmw8zNwl" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://mashable.com/manifest.json?v=m2Pmw8zNwl" rel="manifest"/>
# <link href="https://mashable.com/favicon.ico?v=m2Pmw8zNwl" rel="shortcut icon"/>
# <link href="https://a.amz.mshcdn.com/assets/mashable.touchicon-85568436777b97f88ef7182140a53fd1a4f7cec7c0fa5568a3783fcdb0d08eb5.png" rel="apple-touch-icon-precomposed"/>
# <meta content="no" name="apple-mobile-web-app-capable"/>
# <meta content="MASHABLEV1" name="zd_ptax_version"/>
# <meta content="apps-software,dev-design,node.js,python,ruby,static-website,tech,uncategorized,website-creation" name="zd_ptax"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="#da532c" name="msapplication-TileColor"/>
# <meta content="/mstile-144x144.png?v=m2Pmw8zNwl" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="mid:12105681" name="linkedin:owner"/>
# <meta content="122071082108" property="fb:app_id"/>
# <meta content="18807449704" property="fb:page_id"/>
# <meta content="nYmtX7H2sSCkK8gHpQGxr7Es2526DgUaqb6PGYSX" name="readability-verification"/>
# <meta content="ISmVjY0eCaVFwlI2F32P2rGooLW0ZJi4tAbKmMAapzM" name="google-site-verification"/>
# <link data-page-subject="true" href="https://mashable.com/2014/08/28/static-website-generators/" rel="canonical"/><link data-page-subject="true" href="https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F1200x627.jpg?signature=yBUh5zWmwdXaL9bW9zdjsIMzFc4=" rel="image_src"/><meta content="https://mashable.com/2014/08/28/static-website-generators/" data-page-subject="true" property="og:url"/><meta content="13 Static Site Generators to Help You Build Your Ultimate Website" data-page-subject="true" property="og:title"/><meta content="article" data-page-subject="true" property="og:type"/><meta content="Mashable" data-page-subject="true" property="og:site_name"/><meta content="Websites are becoming leaner, faster and more agile, as users demand quick, seamless experiences. The solution is to utilize a lightweight, static website generator, which can m..." data-page-subject="true" property="og:description"/><meta content="https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F1200x627.jpg?signature=yBUh5zWmwdXaL9bW9zdjsIMzFc4=" data-page-subject="true" property="og:image"/><meta content="2014-08-28T11:15:22Z" data-page-subject="true" property="og:article:published_time"/><meta content="2014-08-28T11:19:25Z" data-page-subject="true" property="og:article:modified_time"/><meta content="https://www.facebook.com/mashable" data-page-subject="true" property="og:article:publisher"/><meta content="Websites are becoming leaner, faster and more agile, as users demand quick, seamless experiences. The solution is to utilize a lightweight, static website generator, which can m..." data-page-subject="true" name="description"/><meta content="python, ruby, node.js, uncategorized, website-creation, tech, apps-software, dev-design, static-website" data-page-subject="true" name="keywords"/><meta content="13 Static Site Generators to Help You Build Your Ultimate Website" data-page-subject="true" name="twitter:title"/><meta content="Websites are becoming leaner, faster and more agile, as users demand quick, seamless experiences. The solution is to utilize a lightweight, static website generator, which can make building and mainta..." data-page-subject="true" name="twitter:description"/><meta content="https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F640x360.jpg?signature=84Luw4081wZ7V8tImw61_eYT2UM=" data-page-subject="true" name="twitter:image"/><meta content="@mashable" data-page-subject="true" name="twitter:site"/><meta content="mashable" data-page-subject="true" name="twitter:via"/><meta content="https://mashable.com/2014/08/28/static-website-generators/" data-page-subject="true" name="twitter:url"/><meta content="@mashable" data-page-subject="true" name="twitter:creator"/><meta content="photo" data-page-subject="true" name="twitter:card"/><meta content="640" data-page-subject="true" name="twitter:image:width"/><meta content="360" data-page-subject="true" name="twitter:image:height"/><meta content="2014-08-28 11:15:22 UTC" data-page-subject="true" name="date"/><meta content="Grace Smith" data-page-subject="true" name="sailthru.author"/><meta content="https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F115x115.jpg?signature=oWx5G2hY9P61BmH-0iV7NpRE-TE=" data-page-subject="true" name="sailthru.image.thumb"/><meta content="https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F950x534__filters%253Aquality%252880%2529.jpg?signature=0xumFqCna6GGL1UL2y55zX77tpY=" data-page-subject="true" name="sailthru.image.full"/><meta content="https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F600x338.jpg?signature=9hzDGdexBrNi_2nysKQlA7IOpC0=" data-page-subject="true" name="sailthru.lead_image"/><meta content="https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F288x162.jpg?signature=AytAFlFklX_TaMAekv0o2Ov6I1s=" data-page-subject="true" nam ...
# <script src="https://cdn.optimizely.com/js/58011369.js"></script>
# <script src="https://content.jwplatform.com/libraries/hrrl7x1B.js"></script>
# <script debug="false" src="https://a.amz.mshcdn.com/assets/advertisement-05dc9dd632adb4df020fc426e931cbf5c678486fac51ea65ff563a9f577dc7bc.js"></script>
# <script debug="false" src="https://a.amz.mshcdn.com/assets/templates-ef27ccb02ffb0b1030369a652d6d1475b5f4222f553aa277eba940a3ecb80500.js"></script>
# <script src="https://a.amz.mshcdn.com/assets/app-8d6c90456d3a652c697c73edfdef14c4c3134717a2b9aab9ca53b0ce59f1fc56.js"></script>
# <script charset="utf-8" src="https://sleeknotecustomerscripts.sleeknote.com/11853.js" type="text/javascript"></script>
# </head>
# <body class="body_posts body_show" data-authorid="7282" data-caninterrupt="" data-jsid="posts/show" data-postid="2820899" data-sec0="tech" data-sec1="" data-sec2="posts" data-topic="devdesign,tech" viewport="fixed">
# <script src="https://cdn.static.zdbb.net/js/z0WVjCBSEeGLoxIxOQVEwQ.min.js" type="text/javascript"></script>
# <script async="true" src="https://cdn.ziffstatic.com/jst/zdconsent.js" type="text/javascript"></script>
# <noscript>
# <img alt="" height="1" src="https://zdbb.net/l/z0WVjCBSEeGLoxIxOQVEwQ" style="display: none;" width="1"/>
# </noscript>
# <script async="async" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js" type="text/javascript"></script>
# <script>
#   mashKit.gdpr.trackerFactory(function() {
#     var OneSignal = window.OneSignal || [];
#     OneSignal.push(function() {
#       OneSignal.init({ appId: "bb9dd396-47e2-47c6-a971-56482269a79b" });
#     });
#   }).render();
# </script>
# <header id="flyout-container"></header>
# <div id="peek">
# <div id="sticky">
# <div class="cookie-notice">
# <div class="wrap">
# We're using cookies to improve your experience.
# <a class="cta" href="/cookie-policy/">Click Here to find out more.</a>
# <div class="dismiss"></div>
# </div>
# </div>
# <header id="site-header"><div class="navbar">
# <div class="navbar-inner"><ul class="in inline js-campaign-analytics main-menu nav">
# <li class="menu"><a class="icon-reorder" href="#">
# <span class="hidden-description">
# Hidden main menu item
# </span>
# </a></li>
# <li class="in logo"><a class="brand" data-turbo-target="body-container" href="/"><span>Mashable</span>
# <img alt="Header logo.v2.in 4d5f1a092c48e9233425f15c44f25a7c0cbed1bedbd8335160519124df085d70" class="light" src="https://a.amz.mshcdn.com/assets/header_logo.v2.in-4d5f1a092c48e9233425f15c44f25a7c0cbed1bedbd8335160519124df085d70.png"/><img alt="Header logo.v2.in.dark 6b9cbc5f71f93f6822d795def6fd049efa1fd58bd0ec75e1b05a734c28972a35" class="dark" src="https://a.amz.mshcdn.com/assets/header_logo.v2.in.dark-6b9cbc5f71f93f6822d795def6fd049efa1fd58bd0ec75e1b05a734c28972a35.png"/></a></li>
# <li class="channel" data-channel="Video" data-tags="mashable-video,scamalot,plugged-in,tl-dw,wtf-history"><a data-campaign="mash-prod-nav-ch" href="/videos/">Video</a></li>
# <li class="collapsable channel submenu" data-channel="Entertainment" data-tags="movies,gaming,television"><a data-campaign="mash-prod-nav-ch" href="/entertainment/">Entertainment</a><div class="submenu-content js-campaign-analytics">
# <div>
# <div class="page-container">
# <ul class="channels">
# <li>
# <a class="subnav-channel" data-campaign="mash-prod-nav-sub" data-category="Movies" data-cid="nav-sub" data-tag="movies" href="/category/movies/">Movies</a>
# </li>
# <li>
# <a class="subnav-channel" data-campaign="mash-prod-nav-sub" data-category="Gaming" data-cid="nav-sub" data-tag="gaming" href="/category/gaming/">Gaming</a>
# </li>
# <li>
# <a class="subnav-channel" data-campaign="mash-prod-nav-sub" data-category="Television" data-cid="nav-sub" data-tag="television" href="/category/television/">Television</a>
# </li>
# </ul>
# </div>
# </div>
# </div></li>
# <li class="collapsable channel submenu" data-channel="Culture" data-tags="web-culture,sex,celebrities,memes,parenting,social-media"><a data-campaign="mash-prod-nav-ch" href="/culture/">Culture</a><div class="submenu-content js-campaign-analytics">
# <div>
# <div class="page-container">
# <ul class="channels">
# <li>
# <a class="subnav-channel" data-campaign="mash-prod-nav-sub" data-category="Web Culture" data-cid="nav-sub" data-tag="web-culture" href="/category/web-culture/">Web Culture</a>
# </li>
# <li>
# <a class="subnav-channel" data-campaign="mash-prod-nav-sub" data-category="Sex &amp; Relationships" data-cid="nav-sub" data-tag="sex" href="/category/sex/">Sex &amp; Relationships</a>
# </li>
# <li>
# <a class="subnav-channel" data-campaign="mash-prod-nav-sub" data-category="Celebrities" data-cid="nav-sub" data-tag="celebrities" href="/category/celebrities/">Celebrities</a>
# </li>
# <li>
# <a class="subnav-channel" data-campaign="mash-prod-nav-sub" data-category="Memes" data-cid="nav-sub" data-tag="memes" href="/category/memes/">Memes</a>
# </li>
# <li>
# <a class="subnav-channel" data-campaign="mash-prod-nav-sub" data-category="Parenting" data-cid="nav-sub" data-tag="parenting" href="/category/parenting/">Parenting</a>
# </li>
# <li>
# <a class="subnav-channel" data-campaign="mash-prod-nav-sub" data-category="Social Media" data-cid="nav-sub" data-tag="social-media" href="/category/social-media/">Social Media</a>
# </li>
# </ul>
# </div>
# </div>
# </div></li>
# <li class="collapsable channel submenu" data-channel="Tech" data-tags="business,apps,gadgets,reviews,mobile,smart-home,how-to,mashable-choice"><a data-campaign="mash-prod-nav-ch" href="/tech/">Tech</a><div class="submenu-content js-campaign-analytics">
# <div>
# <div class="page-container">
# <ul class="channels">
# <li>
# <a class="subnav-channel" data-campaign="mash-prod-nav-sub" data-category="Business" data-cid="nav-sub" data-tag="business" href="/business/">Business</a>
# </li>
# <li>
# <a class="subnav-channel" data-campaign="mash-prod-nav-sub" data-category="Apps" data-cid="nav-sub" data-tag="apps" href="/category/apps/">Apps</a>
# </li>
# <li>
# <a class="subnav-channel" data-campaign="mash-prod-nav-sub" data-category="Gadgets" data-cid="nav-sub" data-tag="gadgets" href="/category/gadgets/">Gadgets</a>
# </li>
# <li>
# <a class="subnav-channel" data-campaign="mash-prod-nav-sub" data-category="Reviews" data-cid="nav-sub" data-tag="reviews" href="/category/reviews/">Reviews</a>
# </li>
# <li>
# <a class="subnav-channel" data-campaign="mash-prod-nav-sub" data-category="Mobile" data-cid="nav-sub" data-tag="mobile" href="/category/mobile/">Mobile</a>
# </li>
# <li>
# <a class="subnav-channel" data-campaign="mash-prod-nav-sub" data-category="Smart Home" data-cid="nav-sub" data-tag="smart-home" href="/category/smart-home/">Smart Home</a>
# </li>
# <li>
# <a class="subnav-channel" data-campaign="mash-prod-nav-sub" data-category="How To" data-cid="nav-sub" data-tag="how-to" href="/category/how-to/">How To</a>
# </li>
# <li>
# <a class="subnav-channel" data-campaign="mash-prod-nav-sub" data-category="Mashable Choice" data-cid="nav-sub" data-tag="mashable-choice" href="/category/mashable-choice/">Mashable Choice</a>
# </li>
# </ul>
# </div>
# </div>
# </div></li>
# <li class="collapsable channel submenu" data-channel="Science" data-tags="climate,space"><a data-campaign="mash-prod-nav-ch" href="/science/">Science</a><div class="submenu-content js-campaign-analytics">
# <div>
# <div class="page-container">
# <ul class="channels">
# <li>
# <a class="subnav-channel" data-campaign="mash-prod-nav-sub" data-category="Climate" data-cid="nav-sub" data-tag="climate" href="/category/climate/">Climate</a>
# </li>
# <li>
# <a class="subnav-channel" data-campaign="mash-prod-nav-sub" data-category="Space" data-cid="nav-sub" data-tag="space" href="/category/space/">Space</a>
# </li>
# </ul>
# </div>
# </div>
# </div></li>
# <li class="collapsable channel submenu" data-channel="Social Good" data-tags="lgbtq,feminism,gender-equality,activism,charity"><a data-campaign="mash-prod-nav-ch" href="/social-good/">Social Good</a><div class="submenu-content js-campaign-analytics">
# <li class="header"><a href="/category/lifestyle">Best of Lifestyle</a></li><li><a href="/roundup/best-air-fryers">Best Airfryer</a></li><li><a href="/roundup/best-cordless-vacuums">Best Cordless Vacuum</a></li><li><a href="/2018/01/24/best-instant-pot-to-buy-recipes-deals-amazon">Best Instant Pot</a></li><li><a href="/gifts/best-gifts-under-50-dollars">Best Gifts Under $50</a></li><li><a href="/roundup/best-robot-vacuums">Best Robot Vacuums</a></li><li><a href="/roundup/best-vacuums-for-pet-hair">Best Vacuum for Pet Hair</a></li></ul></li></ul>
# </div>
# </div></li>
# <li class="submenu collapsable pull-right" id="sign-in"><a href="/login/"><span>Sign in</span></a></li>
# <li class="follow submenu follow-menu pull-right"><a class="follow-trigger" href="/follow-mashable/"><span class="hidden-description">
# Follow mashable
# </span>
# <span class="fb"></span>
# <span class="tw"></span></a>
# <div class="dropdown-menu pull-right social-badges">
# <ul>
# <li class="facebook-container">
# <a class="social-stub social-share facebook like" data-default="1" data-href="https://facebook.com/mashable" data-shares="2.4m">Like</a>
# </li>
# <li>
# <a class="twitter-follow-button" data-dnt="true" data-show-count="true" data-show-screen-name="false" href="https://twitter.com/mashable">
# Follow
# </a>
# </li>
# <li class="linked-in">
# <script data-counter="right" data-id="200000" type="IN/FollowCompany"></script>
# </li>
# <li>
# <iframe allowtransparency="true" border="0" frameborder="0" height="20" id="tmblrFollowBtn" scrolling="no" width="100"></iframe>
# </li>
# <li>
# <div class="pinterest">
# <a data-pin-do="buttonFollow" href="https://www.pinterest.com/Mashable/">
# Mashable
# </a>
# </div>
# </li>
# <li>
# <a alt="RSS Feed" class="rss" href="http://feeds.mashable.com/Mashable" title="RSS Feed">
# <span class="hidden-description">
# RSS Feed
# </span>
# </a>
# <a alt="Email Subscriptions" class="email" href="/subscriptions/" title="Email Subscriptions">
# <span class="hidden-description">
# Email Subscriptions
# </span>
# </a>
# <div class="more">
# <a href="/follow-mashable">see more  &gt;</a>
# </div>
# </li>
# </ul>
# </div></li>
# <li class="nav-search submenu pull-right"><a class="search-trigger" href="/search/">Search</a>
# <div class="dropdown-content">
# <div class="page-container">
# <div class="header-search-form">
# <form accept-charset="UTF-8" action="/search/" method="get"><div style="margin:0;padding:0;display:inline"><input name="utf8" type="hidden" value="✓"/></div><div class="ie-search-wrapper"><input autocomplete="off" class="header-search" id="q" name="q" title="Search" type="text" value=""/></div>
# <input class="btn btn-primary header-search-submit" name="commit" type="submit" value="Search"/>
# </form><div class="header-search-results"></div>
# </div>
# </div>
# </div></li>
# <li class="submenu more"><a href="#"><!-- %span=t "header.nav.more" -->
# <span>More</span></a>
# <div class="submenu-content">
# <div class="page-container">
# <ul class="columns"><li><ul class="column-list"><li class="header">Channels</li>
# </li>
# </div>
# </ul></li></ul>
# </div>
# </div></li>
# </ul></div>
# </div>
# <div id="sticky-slot"></div></header>
# </div>
# <div id="scrollable"><div class="loader"></div>
# <div id="srvSlot" style="position: absolute"><div class="ad_container ad-slot" data-overrides='{"targeting":{"tile":4,"adnum":4,"sec0":"tech","sec1":"","sec2":"posts","topic":"devdesign,tech","postid":2820899,"authorid":7282}}' data-type="survey"></div></div>
# <header class="box970" id="lead-banner">
# <div class="page-container"><center class="visible-desktop">
# <div class="ad_container ad-slot" data-overrides='{"targeting":{"tile":5,"adnum":1,"sec0":"tech","sec1":"","sec2":"posts","topic":"devdesign,tech","postid":2820899,"authorid":7282}}' data-type="desktop_banner"></div>
# </center></div>
# </header><div class="posts show" id="body-container"><div id="main">
# <div class="page-container">
# <div class="body"><script>
#   window.__instream_video = {"player":{"description":"The quotes don't jibe with Tesla's previous statements.","image":"https://mondrian.mashable.com/uploads%252Fvideo_uploaders%252Fdistribution_thumb%252Fimage%252F92466%252F2278a3ce-7555-495c-9380-2910ba243fc8.png%252Foriginal.png?signature=7VKxOj0sywYNGYQi0R00ac1I_ro=&source=https%3A%2F%2Fblueprint-api-production.s3.amazonaws.com","mediaid":"67n7ZY3E0P","preload":false,"title":"Tesla announces its own insurance policy, with a catch","sources":[{"file":"https://vdist.aws.mashable.com/cms/2019/8/097dff6b-2d9a-4d32/hls.m3u8"},{"file":"https://vdist.aws.mashable.com/cms/2019/8/097dff6b-2d9a-4d32/dash.mpd"},{"file":"https://vdist.aws.mashable.com/cms/2019/8/097dff6b-2d9a-4d32/mp4/1080.mp4"},{"file":"https://vdist.aws.mashable.com/cms/2019/8/097dff6b-2d9a-4d32/mp4/720.mp4"},{"file":"https://vdist.aws.mashable.com/cms/2019/8/097dff6b-2d9a-4d32/mp4/480.mp4"}]},"options":{"disableAds":false,"disableSharing":false,"nextupAction":"autoplay","embedUrl":"https://mashable.com/videos/blueprint:67n7ZY3E0P/embed/?player=offsite","standaloneUrl":"https://mashable.com/videos/blueprint:67n7ZY3E0P/","post":{"url":"https://mashable.com/video/tesla-insurance-policy-prices-california/","date":"2019-08-29T19:39:58.642Z","bp_id":102096,"wp_id":null}},"advertising":{"params":{"keywords":"tech,cars,mashable-video,tesla,elon musk","sec0":null,"sec1":"","prc":""}},"analytics":{"labels":"tech,cars,mashable-video,tesla,elon musk","videoSeriesName":null}};
# </script>
# <hgroup class="channel page-header post-head" data-channel="tech" data-section="sec0=tech&amp;sec1=index&amp;sec2=">
# <h2>Tech</h2>
# <div class="follow-channel">
# <div class="follow-buttons">
# <a class="social-stub social-share facebook like" data-default="1" data-href="https://facebook.com/mashable" data-shares="1.7m">Like</a>
# <a class="social-stub social-share twitter follow" data-shares="3.7m" href="https://twitter.com/intent/follow?region=follow_link&amp;screen_name=mashable&amp;tw_p=followbutton&amp;variant=2.0" target="_blank">Follow</a>
# </div>
# </div>
# </hgroup>
# <div class="flex-box article-container">
# <div class="box-cell">
# <div class="above_960 adsense outside_post">
# <script>
#   if(typeof(google_num_ads) != "undefined") google_skip = google_num_ads;
#   google_ad_client = "pub-9942038924324175";
#   if($('.adsense').last().filter('.above_960').length > 0 && $(document).width() < 960){
#     var hideAd = true;
#   }else{
#     var hideAd = false;
#   }
# </script>
# <script>
#   if(!hideAd) google_ad_slot = "3991492827";
# </script>
# <script>
#   if(!hideAd) google_ad_width = 728;
# </script>
# <script>
#   if(!hideAd) google_ad_height = 15;
# </script>
# <script src="https://pagead2.googlesyndication.com/pagead/show_ads.js"></script>
# </div>
# <div class="post-content">
# <script>
#   window.variationsData = []
# </script>
# <div class="post-slider"><article class="full post story" data-channel="Tech" data-id="53ff0f4d97b2f81f900041b5" data-story-type="standard" data-subchannels="" data-topic="devdesign,tech" data-wp-id="2820899">
# <header class="article-header">
# <h1 class="title" href="https://mashable.com/2014/08/28/static-website-generators/">13 Static Site Generators to Help You Build Your Ultimate Website</h1>
# <script>
#   window.variationsTitleElem = 'article header h1.title';
# </script>
# <aside class="shares social">
# <div class="share-buttons">
# <div class="share-button-boxy"><a class="social-stub social-share facebook" data-image="https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F1200x630.jpg?signature=DDO9fFDPJUbXaMVx-qpIlpJaaZg=" data-shares="707" data-title="null" data-uid="bPQn" href="#" title="Like on Facebook">Share</a></div>
# <div class="share-button-boxy"><a class="social-stub social-share twitter" data-shares="918" data-uid="bPQn" href="https://twitter.com/intent/tweet?original_referer=https://mashable.com/&amp;source=tweetbutton&amp;text=13+Static+Site+Generators+to+Help+You+Build+Your+Ultimate+Website&amp;url=https%3A%2F%2Fmashable.com%2F2014%2F08%2F28%2Fstatic-website-generators%2F&amp;via=mashable" title="Tweet on Twitter">Tweet</a></div>
# <div class="share-button-boxy"><a class="social-stub social-share linked_in" data-image="https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F1200x630.jpg?signature=DDO9fFDPJUbXaMVx-qpIlpJaaZg=" data-shares="169" data-title="null" data-uid="bPQn" href="#" title="Share on LinkedIn">Share</a></div>
# <div class="share-button-boxy"><a class="social-stub social-share stumble_upon" data-image="https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F1200x630.jpg?signature=DDO9fFDPJUbXaMVx-qpIlpJaaZg=" data-shares="2419" data-title="null" data-uid="bPQn" href="#" title="Submit to Stumbleupon">Share</a></div>
# <div class="share-button-boxy"><a class="social-stub social-share pinterest" data-image="https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F1200x630.jpg?signature=DDO9fFDPJUbXaMVx-qpIlpJaaZg=" data-shares="1" data-title="null" data-uid="bPQn" href="#" title="Pin to Pinterest">Share</a></div>
# </div>
# </aside>
# <div class="above_960 adsense">
# <script>
#   if(typeof(google_num_ads) != "undefined") google_skip = google_num_ads;
#   google_ad_client = "pub-9942038924324175";
#   if($('.adsense').last().filter('.above_960').length > 0 && $(document).width() < 960){
#     var hideAd = true;
#   }else{
#     var hideAd = false;
#   }
# </script>
# <script>
#   if(!hideAd) google_ad_channel = "9077376301";
# </script>
# <script>
#   if(!hideAd) google_ad_output = "js";
# </script>
# <script>
#   if(!hideAd) google_max_num_ads = "3";
# </script>
# <script>
#   if(!hideAd) google_ad_type = "text";
# </script>
# <script>
#   if(!hideAd) google_feedback = "on";
# </script>
# <script src="https://pagead2.googlesyndication.com/pagead/show_ads.js"></script>
# </div>
# <figure class="article-image"><figure class="image">
# <img alt="" class="microcontent" data-fragment="lead-image" data-image="https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F950x534__filters%253Aquality%252880%2529.jpg?signature=0xumFqCna6GGL1UL2y55zX77tpY=" data-micro="1" naturalwidth="950" sizes="(max-width: 300px) 280px,(max-width: 400px) 356px,(max-width: 700px) 638px,950px" src="https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F950x534__filters%253Aquality%252880%2529.jpg?signature=0xumFqCna6GGL1UL2y55zX77tpY=" srcset="https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F280x157__filters%253Aquality%252880%2529.jpg?signature=4Io4SH--qJNltI0sW_FKo8Tryvw= 280w,https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F356x205__filters%253Aquality%252880%2529.jpg?signature=-nVUR2sLe5OnuAhcTdR53yBrclI= 356w,https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F638x368__filters%253Aquality%252880%2529.jpg?signature=ZJZmeT2Z8JDduuRgGzxB_kvGl3k= 638w,https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F950x534__filters%253Aquality%252880%2529.jpg?signature=0xumFqCna6GGL1UL2y55zX77tpY= 950w"/>
# <div class="image-credit">
# Image: Getty Creative,  vasabii
# </div>
# </figure>
# </figure>
# <div class="article-info"><span class="byline "><span class="author_name">By <a href="/author/grace-smith/">Grace Smith</a></span><time datetime="Thu, 28 Aug 2014 11:15:22 +0000">2014-08-28 11:15:22 UTC</time></span></div>
# </header>
# <section class="article-content">
# <p>Websites are becoming leaner, faster and more agile, as users demand quick, seamless experiences. The solution is to utilize a lightweight, static website generator, which can make building and maintaining websites incredibly simple, as there is no database to slow requests down, and web servers automatically cache headers, reducing bandwidth usage. </p>
# <p>Static sites also offer greater security, as they do not contain dynamic content, so are immune to the most common attacks. Storing content in flat, text files, makes them ideal to be used with version control systems, such as Git. Utilizing a static site generator means you can build websites with modern frameworks, and workflows, with a high degree of productivity and efficiency. </p>
# <p>We have compiled 13 of the best static site generators, which are easy to scale, offer secure filesystems, increased performance and are quick to setup. </p>
# <section class="gallery" data-id="18339" data-slug="static-website-generators">
# <header>
# <h1>Static Website Generators</h1>
# </header>
# <ol class="slides">
# <li class="slide" data-content-source="Gallery - Default" data-id="53ff103db589e470ea006580" data-skip-rerender="false" data-thumb="https://mondrian.mashable.com/wp-content%252Fgallery%252Fstatic-website-generators%252F1-jekyll.jpg%252F180x140.jpg?signature=0TEeC0_r5GXe6j67PvFhGZ6Sth0=&amp;source=https%3A%2F%2Fmashable.com">
# <figure>
# <img alt="Jekyll is a simple, user friendly static site generator powered by Ruby, and is also the engine behind GitHub Pages.
#
# It takes a template directory containing raw text files, runs it through Markdown (Liquid or Textile) convertors, and generates a complete ready-to-publish static website. It features code highlighting, using Pygment's syntax highlighter, with an automatically organized site structure.
#
# It's easy to import content from other blogs, with WordPress, Drupal, Tumblr and even RSS and CSV formats supported. Using the built-in server you can start your own static server from its source code and template and style your website using Markdown. It's incredibly simple to setup, and even easier to start creating blog posts, with templates and layout controls, and a multitude of configuration options." src="https://mondrian.mashable.com/wp-content%252Fgallery%252Fstatic-website-generators%252F1-jekyll.jpg%252Ffit-in__850x850.jpg?signature=vHTPPaBBHwj1o8BZosu6B5KHyy0=&amp;source=https%3A%2F%2Fmashable.com"/>
# </figure>
# <div class="meta">
# <h2 class="title">1. <a href="http://jekyllrb.com/" target="_blank">Jekyll</a>
# </h2>
# <div class="caption">
# <p>Jekyll is a simple, user friendly static site generator powered by Ruby, and is also the engine behind GitHub Pages. </p>
# <p>It takes a template directory containing raw text files, runs it through Markdown (Liquid or Textile) convertors, and generates a complete ready-to-publish static website. It features code highlighting, using Pygment's syntax highlighter, with an automatically organized site structure. </p>
# <p>It's easy to import content from other blogs, with WordPress, Drupal, Tumblr and even RSS and CSV formats supported. Using the built-in server you can start your own static server from its source code and template and style your website using Markdown. It's incredibly simple to setup, and even easier to start creating blog posts, with templates and layout controls, and a multitude of configuration options. </p>
# </div>
# <div class="credit">
# </div>
# </div>
# </li>
# <li class="slide" data-content-source="Gallery - Default" data-id="53ff103db589e470ea006581" data-skip-rerender="false" data-thumb="https://mondrian.mashable.com/wp-content%252Fgallery%252Fstatic-website-generators%252F2-octopress.jpg%252F180x140.jpg?signature=MAw7QsrOpqXYRn2cEiH9Fc7BbaI=&amp;source=https%3A%2F%2Fmashable.com">
# <figure>
# <img alt="Octopress is a framework designed for Jekyll, a static blogging engine powering GitHub Pages, and makes blogging easy and beautiful, sporting a clean, responsive theme written in semantic HTML5.
#
# Octopress has built-in integration with Twitter, Google Analytics, Google Plus, Pinboard, Disqus Comments and other services. It also includes a preview server for local staging, which will regenerate your site on-the-fly as you make changes. The collection of rake tasks simplifies development and makes deployment simple. Using the Octopress rake file lets you isolate a single post so that only that post will be generated locally, for a quick testing cycle. You can use both Jekyll plugins and those built specifically for Octopress, as well as those from third party developers." src="https://mondrian.mashable.com/wp-content%252Fgallery%252Fstatic-website-generators%252F2-octopress.jpg%252Ffit-in__850x850.jpg?signature=CC6AFH2S4EavRu9UPgM6oYJ3EwE=&amp;source=https%3A%2F%2Fmashable.com"/>
# </figure>
# <div class="meta">
# <h2 class="title">2. <a href="http://octopress.org/" target="_blank">Octopress</a>
# </h2>
# <div class="caption">
# <p>Octopress is a framework designed for Jekyll, a static blogging engine powering GitHub Pages, and makes blogging easy and beautiful, sporting a clean, responsive theme written in semantic HTML5. </p>
# <p>Octopress has built-in integration with Twitter, Google Analytics, Google Plus, Pinboard, Disqus Comments and other services. It also includes a preview server for local staging, which will regenerate your site on-the-fly as you make changes. The collection of rake tasks simplifies development and makes deployment simple. Using the Octopress rake file lets you isolate a single post so that only that post will be generated locally, for a quick testing cycle. You can use both Jekyll plugins and those built specifically for Octopress, as well as those from third party developers. </p>
# </div>
# <div class="credit">
# </div>
# </div>
# </li>
# <li class="slide" data-content-source="Gallery - Default" data-id="53ff103db589e470ea006582" data-skip-rerender="false" data-thumb="https://mondrian.mashable.com/wp-content%252Fgallery%252Fstatic-website-generators%252F3-docpad.jpg%252F180x140.jpg?signature=6TWVlLuk193DZkCGivQ0ONnRneo=&amp;source=https%3A%2F%2Fmashable.com">
# <figure>
# <img alt="DocPad is a static website generator built on Node.js and Express.js, that empowers your website with layouts, pre-processors, querying and a robust plugin system.
#
# It comes integrated with an administrator dashboard to make publishing easier. Provided you have the right rendering plugin, you can use any templating engine you prefer, on a document-by-document basis. Since it's modular-based it's incredibly easy to extend, and is able to generate documents dynamically at runtime.
#
# There are a wealth of pre-built skeletons available to help you get started, including a HTML5 Boilerplate, Twitter Bootstrap, ZURB Foundation and lots more. Versioning support means you can keep track of the changes you make in your project." src="https://mondrian.mashable.com/wp-content%252Fgallery%252Fstatic-website-generators%252F3-docpad.jpg%252Ffit-in__850x850.jpg?signature=cDj-3XatZTA8EXKFBzubTcbRC50=&amp;source=https%3A%2F%2Fmashable.com"/>
# </figure>
# <div class="meta">
# <h2 class="title">3. <a href="http://docpad.org/" target="_blank">DocPad</a>
# </h2>
# <div class="caption">
# <p>DocPad is a static website generator built on Node.js and Express.js, that empowers your website with layouts, pre-processors, querying and a robust plugin system. </p>
# <p>It comes integrated with an administrator dashboard to make publishing easier. Provided you have the right rendering plugin, you can use any templating engine you prefer, on a document-by-document basis. Since it's modular-based it's incredibly easy to extend, and is able to generate documents dynamically at runtime. </p>
# <p>There are a wealth of pre-built skeletons available to help you get started, including a HTML5 Boilerplate, Twitter Bootstrap, ZURB Foundation and lots more. Versioning support means you can keep track of the changes you make in your project.</p>
# </div>
# <div class="credit">
# </div>
# </div>
# </li>
# <li class="slide" data-content-source="Gallery - Default" data-id="53ff103db589e470ea006583" data-skip-rerender="false" data-thumb="https://mondrian.mashable.com/wp-content%252Fgallery%252Fstatic-website-generators%252F4-hugo.jpg%252F180x140.jpg?signature=l_tZzbshdog849tMcG4Dsr2dJsE=&amp;source=https%3A%2F%2Fmashable.com">
# <figure>
# <img alt="Hugo is a fast, modern static website engine with a high degree of flexibility. It doesn't depend on administrative privileges, databases, runtimes, interpreters or external libraries, and can be installed and run however you wish, and then deployed on Amazon S3, GitHub Pages, Dropbox or any web host you choose.
#
# Hugo was written for speed and performance, and allows you to organize your content however you want with any URL structure. You can declare your own content types, define your own metadata and use indexes to group your content. You can write content in Markdown, render changes on the fly as you develop, with support for Disqus Comments, dynamic menu creation, pretty urls, syntax highlighting and more." src="https://mondrian.mashable.com/wp-content%252Fgallery%252Fstatic-website-generators%252F4-hugo.jpg%252Ffit-in__850x850.jpg?signature=OVTcPKQpp21Foj3WsAf-ZrnHBSc=&amp;source=https%3A%2F%2Fmashable.com"/>
# </figure>
# <div class="meta">
# <h2 class="title">4. <a href="http://hugo.spf13.com/" target="_blank"></a>Hugo</h2>
# <div class="caption">
# <p>Hugo is a fast, modern static website engine with a high degree of flexibility. It doesn't depend on administrative privileges, databases, runtimes, interpreters or external libraries, and can be installed and run however you wish, and then deployed on Amazon S3, GitHub Pages, Dropbox or any web host you choose. </p>
# <p>Hugo was written for speed and performance, and allows you to organize your content however you want with any URL structure. You can declare your own content types, define your own metadata and use indexes to group your content. You can write content in Markdown, render changes on the fly as you develop, with support for Disqus Comments, dynamic menu creation, pretty urls, syntax highlighting and more. </p>
# </div>
# <div class="credit">
# </div>
# </div>
# </li>
# <li class="slide" data-content-source="Gallery - Default" data-id="53ff103db589e470ea006584" data-skip-rerender="false" data-thumb="https://mondrian.mashable.com/wp-content%252Fgallery%252Fstatic-website-generators%252F5-wintersmith.jpg%252F180x140.jpg?signature=v_Cka9yE9GtojUtQqutDL7VIHhA=&amp;source=https%3A%2F%2Fmashable.com">
# <figure>
# <img alt="Wintersmith is a flexible, minimalistic, multi-platform static site generator built on top of Node.js.
#
# It puts absolutely no limits on how you work with your content, and you can transform it with plugins and structure it as you please. Wintersmith comes bundled with a Jade plugin, with community-made plugins available, and you can use your favorite templating engine. Deployment is simple, and there's no need for special hosting solutions and the performance is blazing fast as there are no database calls, no server-side API calls or any CPU/RAM overhead.
#
# Once installed, Wintersmith will create a basic structure for your site, including a contents folder that contains all of your assets and your content written in Markdown of JSON files. The templates contains your templates and the config.json file is where you put any global options." src="https://mondrian.mashable.com/wp-content%252Fgallery%252Fstatic-website-generators%252F5-wintersmith.jpg%252Ffit-in__850x850.jpg?signature=cQidCiPNOGOgCrcPUwdhBo8oA80=&amp;source=https%3A%2F%2Fmashable.com"/>
# </figure>
# <div class="meta">
# <h2 class="title">5. <a href="http://wintersmith.io/" target="_blank">Wintersmith</a>
# </h2>
# <div class="caption">
# <p>Wintersmith is a flexible, minimalistic, multi-platform static site generator built on top of Node.js. </p>
# <p>It puts absolutely no limits on how you work with your content, and you can transform it with plugins and structure it as you please. Wintersmith comes bundled with a Jade plugin, with community-made plugins available, and you can use your favorite templating engine. Deployment is simple, and there's no need for special hosting solutions and the performance is blazing fast as there are no database calls, no server-side API calls or any CPU/RAM overhead. </p>
# <p>Once installed, Wintersmith will create a basic structure for your site, including a contents folder that contains all of your assets and your content written in Markdown of JSON files. The templates contains your templates and the config.json file is where you put any global options. </p>
# </div>
# <div class="credit">
# </div>
# </div>
# </li>
# <li class="slide" data-content-source="Gallery - Default" data-id="53ff103db589e470ea006585" data-skip-rerender="false" data-thumb="https://mondrian.mashable.com/wp-content%252Fgallery%252Fstatic-website-generators%252F6-middleman.jpg%252F180x140.jpg?signature=M8N4uz-vPdoT-9AA1wn4wCxWvl0=&amp;source=https%3A%2F%2Fmashable.com">
# <figure>
# <img alt="Middleman is a command-line tool for creating static websites, with Ruby and the Sinatra web framework forming the base of the tool.  With Middleman you have standalone developer access to ERb, Haml, Sass for DRY stylesheets, CoffeeScript for safer, less verbose Javascript and multiple asset management solutions, including Sprockets.
#
# ...
# <p>The recently released Cactus 3 features asset fingerprinting, asset pipeline, pretty URLs, native OS X filesystem events, automatic nameserver configuration, support for multiple deployment backends and more. It's incredibly easy to install and generate a new project, and to start editing and previewing your site just point your browser to localhost. Cactus will automatically rebuild your project and refresh your browser once you make changes. </p>
# </div>
# <div class="credit">
# </div>
# </div>
# </li>
# <li class="slide" data-content-source="Gallery - Default" data-id="53ff103eb589e470ea00658b" data-skip-rerender="false" data-thumb="https://mondrian.mashable.com/wp-content%252Fgallery%252Fstatic-website-generators%252F12-pelican.jpg%252F180x140.jpg?signature=dAB3flFodo8IadZ8xa_yAwq95HQ=&amp;source=https%3A%2F%2Fmashable.com">
# <figure>
# <img alt="Pelican is a static site generator powered by Python, that requires no database or sever-side logic. You can write your own content in reStructuredText, Markdown, or AsciiDoc formats and also publish in multiple languages.
#
# Themes can be customized via Jinja tempates, with support for code syntax highlighting, Atom and RSS feeds. Pelican also allows integration with social media accounts and Google Analytics.  The modular plugin system and corresponding plugin repository make it easy to extend the functionality of your site while keeping bloat to a minimum.
#
# Pelican also supports external commenting tools such as Disqus, and allows you to import from Wordpress, Dotclear or RSS feeds." src="https://mondrian.mashable.com/wp-content%252Fgallery%252Fstatic-website-generators%252F12-pelican.jpg%252Ffit-in__850x850.jpg?signature=0VniKXO8NLOEuRmcl6-4R9MDV6A=&amp;source=https%3A%2F%2Fmashable.com"/>
# </figure>
# <div class="meta">
# <h2 class="title">12. <a href="http://blog.getpelican.com/" target="_blank">Pelican</a>
# </h2>
# <div class="caption">
# <p>Pelican is a static site generator powered by Python, that requires no database or sever-side logic. You can write your own content in reStructuredText, Markdown, or AsciiDoc formats and also publish in multiple languages. </p>
# <p>Themes can be customized via Jinja tempates, with support for code syntax highlighting, Atom and RSS feeds. Pelican also allows integration with social media accounts and Google Analytics.  The modular plugin system and corresponding plugin repository make it easy to extend the functionality of your site while keeping bloat to a minimum. </p>
# <p>Pelican also supports external commenting tools such as Disqus, and allows you to import from Wordpress, Dotclear or RSS feeds. </p>
# </div>
# <div class="credit">
# </div>
# </div>
# </li>
# <li class="slide" data-content-source="Gallery - Default" data-id="53ff103eb589e470ea00658c" data-skip-rerender="false" data-thumb="https://mondrian.mashable.com/wp-content%252Fgallery%252Fstatic-website-generators%252F13-sculpin.jpg%252F180x140.jpg?signature=nDSdD2puaSGYIAKPh6FnPzaybbE=&amp;source=https%3A%2F%2Fmashable.com">
# <figure>
# <img alt="Sculpin is a static site generator written in PHP, which converts Markdown files, Twig templates or standard HTML into a static site that can easily be deployed. With the embedded composer you can keep your source control focused and consistent. The in-built Symfony HTTP Kernel lets you use Symfony Bundles to extend Sculpin for any advanced functionality you need, without extending Sculpin directly. Using Twig as the template engine makes it easy to get started quickly, as Twig allows you to define custom tags, and filters, with a sandbox to evaluate untrusted template code." src="https://mondrian.mashable.com/wp-content%252Fgallery%252Fstatic-website-generators%252F13-sculpin.jpg%252Ffit-in__850x850.jpg?signature=SQbDiv5dwP9tLwI9U7VsOPB_Sx0=&amp;source=https%3A%2F%2Fmashable.com"/>
# </figure>
# <div class="meta">
# <h2 class="title">13. <a href="https://sculpin.io/" target="_blank">Sculpin</a>
# </h2>
# <div class="caption"><p>Sculpin is a static site generator written in PHP, which converts Markdown files, Twig templates or standard HTML into a static site that can easily be deployed. With the embedded composer you can keep your source control focused and consistent. The in-built Symfony HTTP Kernel lets you use Symfony Bundles to extend Sculpin for any advanced functionality you need, without extending Sculpin directly. Using Twig as the template engine makes it easy to get started quickly, as Twig allows you to define custom tags, and filters, with a sandbox to evaluate untrusted template code. </p></div>
# <div class="credit">
# </div>
# </div>
# </li>
# </ol>
# </section>
# </section>
# <footer class="article-topics">
# Topics:
# <a href="/category/apps-software/">Apps and Software</a>, <a href="/category/dev-design/">Dev &amp; Design</a>, <a href="/category/node.js">node.js</a>, <a href="/category/python/">Python</a>, <a href="/category/ruby/">ruby</a>, <a href="/category/static-website/">static website</a>, <a href="/category/tech/">Tech</a>, <a href="/category/website-creation/">website creation</a>
# </footer>
# <div id="after-page-recirc"></div>
# <div id="after-page-mobile-recirc"></div>
# <div class="zerg-widgets"><div class="zergnet-container" data-zsection="61189" id="zergnet-widget-61189"></div></div>
# <div data-display-daily-newsletter="show" id="newsletter-signup"></div>
# <script>
#   if (window.pageChanged) {
#     window.omni({"channel":"Tech","content_type":"article","top_channel":"Tech","content_source_type":"Internal","content_source_name":"Internal","author_name":"Grace Smith","age":"1827","pub_day":28,"pub_month":8,"pub_year":2014,"pub_date":"08/28/2014","sourced_from":"Internal","isPostView":true,"post_lead_type":"Default","topics":"apps-software,dev-design,node.js,python,ruby,static-website,tech,uncategorized,website-creation","campaign":null,"display_mode":"list","viral_video_type":null,"standalone_video_show":null,"mash_video_show":null,"b_flag":true,"cms_author_name":null,"cms_author_geo":"us","cms_author_team":null,"bp_id":null,"shoppable":null});
#     metaData = {"link":[["canonical","https://mashable.com/2014/08/28/static-website-generators/"],["image_src","https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F1200x627.jpg?signature=yBUh5zWmwdXaL9bW9zdjsIMzFc4="]],"meta_property":[["og:url","https://mashable.com/2014/08/28/static-website-generators/"],["og:title","13 Static Site Generators to Help You Build Your Ultimate Website"],["og:type","article"],["og:site_name","Mashable"],["og:description","Websites are becoming leaner, faster and more agile, as users demand quick, seamless experiences. The solution is to utilize a lightweight, static website generator, which can m..."],["og:image","https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F1200x627.jpg?signature=yBUh5zWmwdXaL9bW9zdjsIMzFc4="],["og:article:published_time","2014-08-28T11:15:22Z"],["og:article:modified_time","2014-08-28T11:19:25Z"],["og:article:publisher","https://www.facebook.com/mashable"]],"meta_name":[["description","Websites are becoming leaner, faster and more agile, as users demand quick, seamless experiences. The solution is to utilize a lightweight, static website generator, which can m..."],["keywords","python, ruby, node.js, uncategorized, website-creation, tech, apps-software, dev-design, static-website"],["twitter:title","13 Static Site Generators to Help You Build Your Ultimate Website"],["twitter:description","Websites are becoming leaner, faster and more agile, as users demand quick, seamless experiences. The solution is to utilize a lightweight, static website generator, which can make building and mainta..."],["twitter:image","https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F640x360.jpg?signature=84Luw4081wZ7V8tImw61_eYT2UM="],["twitter:site","@mashable"],["twitter:via","mashable"],["twitter:url","https://mashable.com/2014/08/28/static-website-generators/"],["twitter:creator","@mashable"],["twitter:card","photo"],["twitter:image:width","640"],["twitter:image:height","360"],["date","2014-08-28 11:15:22 UTC"],["sailthru.author","Grace Smith"],["sailthru.image.thumb","https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F115x115.jpg?signature=oWx5G2hY9P61BmH-0iV7NpRE-TE="],["sailthru.image.full","https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F950x534__filters%253Aquality%252880%2529.jpg?signature=0xumFqCna6GGL1UL2y55zX77tpY="],["sailthru.lead_image","https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F600x338.jpg?signature=9hzDGdexBrNi_2nysKQlA7IOpC0="],["sailthru.secondary_image","https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F288x162.jpg?signature=AytAFlFklX_TaMAekv0o2Ov6I1s="],["sailthru.exclude_homepage",false],["sailthru.exclude_uk",false],["sailthru.exclude_australia",false],["sailthru.exclude_india",false],["sailthru.exclude_india",false],["sailthru.tags","apps-software,dev-design,node.js,python,ruby,static-website,tech,uncategorized,website-creation"],["sailthru.title","13 Static Site Generators to Help You Build Your Ultimate Website"],["sailthru.date","2014-08-28T11:15:22.000Z"],["author","Grace Smith"]]};
#   }
#
#   mashKit.gdpr.trackerFactory(function() {
#     dom_trackers = {
#       ad_tracker: null,
#       iframes: null,
#       images: null,
#       simplereach: null
#     };
#     for (var tracker in dom_trackers) {
#       $('section.article-content').append(dom_trackers[tracker]);
#     }
#     $('head').append(null)
#   }).render();
# </script>
# </article>
# </div>
# </div>
# </div>
# <aside class="box-cell sidebar">
# <div class="ad sidebar-inset sidebar-drop">
# <div class="ad_container ad-slot" data-overrides='{"targeting":{"tile":1,"adnum":1,"sec0":"tech","sec1":"","sec2":"posts","topic":"devdesign,tech","postid":2820899,"authorid":7282}}' data-type="right_rail"></div>
# </div>
# <div class="sidebar-inset" id="big-stories"></div>
# </aside>
# </div>
# <div id="pathing-banner">
# <div class="ad_container ad-slot" data-overrides='{"targeting":{"tile":2,"adnum":2,"sec0":"tech","sec1":"","sec2":"posts","topic":"devdesign,tech","postid":2820899,"authorid":7282}}' data-type="pathing_banner"></div>
# </div>
# <div id="pathing-recirc"></div>
# <!-- Analytics -->
# <!-- Twitter Ad Tracker -->
# <noscript>
# <img alt="" height="1" src="https://analytics.twitter.com/i/adsct?txn_id=l4o6d&amp;p_id=Twitter" style="display:none;" width="1"/>
# <img alt="" height="1" src="https://t.co/i/adsct?txn_id=l4o6d&amp;p_id=Twitter" style="display:none;" width="1"/>
# </noscript>
# <img alt="Twitter Ad Tracker" class="bluekai-test-img" height="0" src="https://mashable.com/favicon-16x16.png?bk_uuid=$_BK_UUID&amp;BK_SWAP_DEST=19275" width="0"/>
# </div>
# </div>
# <!-- scroll load stub - do not remove -->
# <div class="after-page-container"></div>
# <script id="banner-template" type="text/template">
# <div class='banner-ad-wrapper'>
# <div class="ad_container ad-slot" data-overrides="{&quot;targeting&quot;:{&quot;tile&quot;:3,&quot;adnum&quot;:3,&quot;sec0&quot;:&quot;tech&quot;,&quot;sec1&quot;:&quot;&quot;,&quot;sec2&quot;:&quot;posts&quot;,&quot;topic&quot;:&quot;devdesign,tech&quot;,&quot;postid&quot;:2820899,&quot;authorid&quot;:7282,&quot;ad_num&quot;:1,&quot;pathing&quot;:true,&quot;pathingtype&quot;:&quot;article&quot;}}" data-type="banner"></div>
# </div>
# </script>
# </div><div id="fb-root"></div><script>
#   if(window.initPage) { window.initPage() }
#   else { $(function() { window.initPage && window.initPage(); })}
# </script>
# </div><footer id="site-footer-wrapper">
# <div class="page-container" id="site-footer"><ul class="nav"><li><a href="/about/">About Us</a></li><li><a href="http://jobs.mashable.com">Jobs</a></li><li><a href="/advertise/">Advertise</a></li><li><a href="/2011/05/09/connect-with-mashable/">Subscribe</a></li><li><a href="https://t.yesware.com/tt/71b30593224daffd090ea9e6e9a481b97a93a23e/6192469e5a936fed0f85e635cbb1d635/d7b076cb4f776b359888a0adc1e8ea67/support.stackcommerce.com/hc/en-us/requests/new?persona=Internet+Culture&amp;publisher_id=273&amp;publisher_logo=https%3A%2F%2Fcdnp1.stackassets.com%2Ffe11f98bd7119dad30cf34c37f61e214dc6e61c3%2Fstore%2Ff21e674c706b34333b2a7e45fc05ab8d85be251e7409bd9035d60e3e7f10%2FMashable_Web.png&amp;source=lower+footer+contact+link">Mashable Shop Contact</a></li><li><a href="/privacy/">Privacy</a></li><li><a href="/terms/">Terms</a></li></ul><ul class="social"><li><a class="facebook" href="https://www.facebook.com/mashable/" target="_social">
# <span class="hidden-description">
# Facebook mashable
# </span>
# </a></li>
# <li><a class="twitter" href="https://twitter.com/mashable" target="_social">
# <span class="hidden-description">
# Twitter mashable
# </span>
# </a></li>
# <li><a class="rss" href="http://feeds.mashable.com/Mashable" target="_social">
# <span class="hidden-description">
# Feeds mashable
# </span>
# </a></li>
# <li><a class="pinterest" href="https://pinterest.com/mashable/" target="_social">
# <span class="hidden-description">
# Pinterest mashable
# </span>
# </a></li>
# <li><a class="youtube" href="https://www.youtube.com/user/mashable" target="_social">
# <span class="hidden-description">
# YouTube mashable
# </span>
# </a></li>
# <li><a class="stumbleupon" href="https://www.stumbleupon.com/channel/Mashable" target="_social">
# <span class="hidden-description">
# StumbleUpon mashable
# </span>
# </a></li>
# <li><a class="linkedin" href="https://www.linkedin.com/company/mashable" target="_social">
# <span class="hidden-description">
# LinkedIn mashable
# </span>
# </a></li></ul>
# <div class="about">
# <a class="brand" href="/">
# Mashable
# </a>
# <span class="blurb">is a global, multi-platform media and entertainment company. Powered by its own proprietary technology, Mashable is the go-to source for tech, digital culture and entertainment content for its dedicated and influential audience around the globe.</span>
# </div>
# <div class="copyright-and-legal">
# <div>
# ©2019
# Mashable, Inc. All Rights Reserved.
# </div>
# <div>
# Mashable, MashBash and Mashable House are among the federally registered trademarks of Ziff Davis, LLC and may not be used by third parties without explicit permission.
# </div>
# </div>
# </div>
# </footer>
# <noscript>
# <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=6036202&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# </div>
# </div>
# <script>
#   !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#   n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#   document,'script','https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '1453039084979896');
#   if (window._geo == 'GB') {
#     fbq('init', '322220058389212');
#   }
#
#   if (window.mashKit) {
#     mashKit.gdpr.trackerFactory(function() {
#       fbq('track', "PageView");
#     }).render();
#   }
# </script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=1453039084979896&amp;ev=PageView&amp;noscript=1" style="display: none" width="1"/>
# </noscript>
# <script>
#   window.detectStaffEditableLink && window.detectStaffEditableLink();
# </script>
# <script>
#   if(!window.cnxCommonUtils) {
#     window.cnxCommonUtils = {
#       getHref: function() {
#         return document.location.href;
#       }
#     }
#   }
#   if(!window.getExperimentValue('vendors', 'disableScript', '').match(/connatix/)) {
#     (function(){
#       var s = document.createElement('script');
#       s.async = true;
#       s.type = 'text/javascript';
#       s.src = 'https://cdn.connatix.com/min/connatix.handler.dfp.min.js';
#       (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(s);
#     })();
#   }
# </script>
# </body>
# </html>

# %% [markdown]
# ### Extracting a list of links from a web page using BeautifulSoup

# %% [markdown]
# #### In any webpage links are created inside "a" tag, "link" tag and links for images in "img" tag. Any link should starts with https|http, so to extract only links from tags we should give expression to code so here we are using regular expression filter to extract only links fron tags.

# %% [markdown]
# This code will give list of links which are having the attribute("href") value started with "https"(not include "http") in "a" along with complete content of "a" tag.

# %%
soup.find_all("a",  attrs = {'href': re.compile("^https")})
# Out:
# [<a class="twitter-follow-button" data-dnt="true" data-show-count="true" data-show-screen-name="false" href="https://twitter.com/mashable">
#  Follow
#  </a>,
#  <a data-pin-do="buttonFollow" href="https://www.pinterest.com/Mashable/">
#  Mashable
#  </a>,
#  <a href="https://t.yesware.com/tt/71b30593224daffd090ea9e6e9a481b97a93a23e/6192469e5a936fed0f85e635cbb1d635/d7b076cb4f776b359888a0adc1e8ea67/support.stackcommerce.com/hc/en-us/requests/new?persona=Internet+Culture&amp;publisher_id=273&amp;publisher_logo=https%3A%2F%2Fcdnp1.stackassets.com%2Ffe11f98bd7119dad30cf34c37f61e214dc6e61c3%2Fstore%2Ff21e674c706b34333b2a7e45fc05ab8d85be251e7409bd9035d60e3e7f10%2FMashable_Web.png&amp;source=lower+footer+contact+link">Mashable Shop</a>,
#  <a class="geo" href="https://mashable.com?geo=US&amp;utm_campaign=mash-prod-nav-geo&amp;utm_source=internal&amp;utm_medium=onsite" onclick='$.cookie("geo","US")'>Mashable</a>,
#  <a class="geo" href="https://mashable.com?geo=AU&amp;utm_campaign=mash-prod-nav-geo&amp;utm_source=internal&amp;utm_medium=onsite" onclick='$.cookie("geo","AU")'>Mashable Australia</a>,
#  <a class="geo" href="https://me.mashable.com?geo=ME&amp;utm_campaign=mash-prod-nav-geo&amp;utm_source=internal&amp;utm_medium=onsite" onclick='$.cookie("geo","ME")'>Mashable ME</a>,
#  <a class="geo" href="https://sea.mashable.com?geo=SEA&amp;utm_campaign=mash-prod-nav-geo&amp;utm_source=internal&amp;utm_medium=onsite" onclick='$.cookie("geo","SEA")'>Mashable SE Asia</a>,
#  <a class="geo" href="https://mashable.com?geo=GB&amp;utm_campaign=mash-prod-nav-geo&amp;utm_source=internal&amp;utm_medium=onsite" onclick='$.cookie("geo","GB")'>Mashable UK</a>,
#  <a class="social-stub social-share twitter follow" data-shares="3.7m" href="https://twitter.com/intent/follow?region=follow_link&amp;screen_name=mashable&amp;tw_p=followbutton&amp;variant=2.0" target="_blank">Follow</a>,
#  <a class="social-stub social-share twitter" data-shares="918" data-uid="bPQn" href="https://twitter.com/intent/tweet?original_referer=https://mashable.com/&amp;source=tweetbutton&amp;text=13+Static+Site+Generators+to+Help+You+Build+Your+Ultimate+Website&amp;url=https%3A%2F%2Fmashable.com%2F2014%2F08%2F28%2Fstatic-website-generators%2F&amp;via=mashable" title="Tweet on Twitter">Tweet</a>,
#  <a href="https://github.com/koenbok/Cactus/" target="_blank">Cactus</a>,
#  <a href="https://sculpin.io/" target="_blank">Sculpin</a>,
#  <a href="https://t.yesware.com/tt/71b30593224daffd090ea9e6e9a481b97a93a23e/6192469e5a936fed0f85e635cbb1d635/d7b076cb4f776b359888a0adc1e8ea67/support.stackcommerce.com/hc/en-us/requests/new?persona=Internet+Culture&amp;publisher_id=273&amp;publisher_logo=https%3A%2F%2Fcdnp1.stackassets.com%2Ffe11f98bd7119dad30cf34c37f61e214dc6e61c3%2Fstore%2Ff21e674c706b34333b2a7e45fc05ab8d85be251e7409bd9035d60e3e7f10%2FMashable_Web.png&amp;source=lower+footer+contact+link">Mashable Shop Contact</a>,
#  <a class="facebook" href="https://www.facebook.com/mashable/" target="_social">
#  <span class="hidden-description">
#  Facebook mashable
#  </span>
#  </a>,
#  <a class="twitter" href="https://twitter.com/mashable" target="_social">
#  <span class="hidden-description">
#  Twitter mashable
#  </span>
#  </a>,
#  <a class="pinterest" href="https://pinterest.com/mashable/" target="_social">
#  <span class="hidden-description">
#  Pinterest mashable
#  </span>
#  </a>,
#  <a class="youtube" href="https://www.youtube.com/user/mashable" target="_social">
#  <span class="hidden-description">
#  YouTube mashable
#  </span>
#  </a>,
#  <a class="stumbleupon" href="https://www.stumbleupon.com/channel/Mashable" target="_social">
#  <span class="hidden-description">
#  StumbleUpon mashable
#  </span>
#  </a>,
#  <a class="linkedin" href="https://www.linkedin.com/company/mashable" target="_social">
#  <span class="hidden-description">
#  LinkedIn mashable
#  </span>
#  </a>]

# %% [markdown]
# This code will give only links, which are having the attribute("href") value started with "https"(not include "http") in "a" tag.

# %%
for link in soup.find_all("a",  attrs = {'href': re.compile("^https")}):
    print(link['href'])
# Out:
# https://twitter.com/mashable
# https://www.pinterest.com/Mashable/
# https://t.yesware.com/tt/71b30593224daffd090ea9e6e9a481b97a93a23e/6192469e5a936fed0f85e635cbb1d635/d7b076cb4f776b359888a0adc1e8ea67/support.stackcommerce.com/hc/en-us/requests/new?persona=Internet+Culture&publisher_id=273&publisher_logo=https%3A%2F%2Fcdnp1.stackassets.com%2Ffe11f98bd7119dad30cf34c37f61e214dc6e61c3%2Fstore%2Ff21e674c706b34333b2a7e45fc05ab8d85be251e7409bd9035d60e3e7f10%2FMashable_Web.png&source=lower+footer+contact+link
# https://mashable.com?geo=US&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://mashable.com?geo=AU&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://me.mashable.com?geo=ME&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://sea.mashable.com?geo=SEA&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://mashable.com?geo=GB&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://twitter.com/intent/follow?region=follow_link&screen_name=mashable&tw_p=followbutton&variant=2.0
# https://twitter.com/intent/tweet?original_referer=https://mashable.com/&source=tweetbutton&text=13+Static+Site+Generators+to+Help+You+Build+Your+Ultimate+Website&url=https%3A%2F%2Fmashable.com%2F2014%2F08%2F28%2Fstatic-website-generators%2F&via=mashable
# https://github.com/koenbok/Cactus/
# https://sculpin.io/
# https://t.yesware.com/tt/71b30593224daffd090ea9e6e9a481b97a93a23e/6192469e5a936fed0f85e635cbb1d635/d7b076cb4f776b359888a0adc1e8ea67/support.stackcommerce.com/hc/en-us/requests/new?persona=Internet+Culture&publisher_id=273&publisher_logo=https%3A%2F%2Fcdnp1.stackassets.com%2Ffe11f98bd7119dad30cf34c37f61e214dc6e61c3%2Fstore%2Ff21e674c706b34333b2a7e45fc05ab8d85be251e7409bd9035d60e3e7f10%2FMashable_Web.png&source=lower+footer+contact+link
# https://www.facebook.com/mashable/
# https://twitter.com/mashable
# https://pinterest.com/mashable/
# https://www.youtube.com/user/mashable
# https://www.stumbleupon.com/channel/Mashable
# https://www.linkedin.com/company/mashable

# %% [markdown]
# This code will give only links, which are having the attribute("href") value started with "http://"

# %%
for link in soup.findAll('a', attrs = {"href" : re.compile("^http://")}):
    print(link['href'])
# Out:
# http://feeds.mashable.com/Mashable
# http://jobs.mashable.com
# http://jekyllrb.com/
# http://octopress.org/
# http://docpad.org/
# http://hugo.spf13.com/
# http://wintersmith.io/
# http://middlemanapp.com/
# http://nanoc.ws/
# http://www.metalsmith.io/
# http://hexo.io/index.html
# http://harpjs.com/
# http://blog.getpelican.com/
# http://jobs.mashable.com
# http://feeds.mashable.com/Mashable

# %% [markdown]
# This code will give only links, which are having the attribute("href") value started with both "http" and "https" in "a" tag.

# %%
for link in soup.findAll('a', attrs = {"href" : re.compile("^http|https")}):
    print(link['href'])
# Out:
# https://twitter.com/mashable
# https://www.pinterest.com/Mashable/
# http://feeds.mashable.com/Mashable
# https://t.yesware.com/tt/71b30593224daffd090ea9e6e9a481b97a93a23e/6192469e5a936fed0f85e635cbb1d635/d7b076cb4f776b359888a0adc1e8ea67/support.stackcommerce.com/hc/en-us/requests/new?persona=Internet+Culture&publisher_id=273&publisher_logo=https%3A%2F%2Fcdnp1.stackassets.com%2Ffe11f98bd7119dad30cf34c37f61e214dc6e61c3%2Fstore%2Ff21e674c706b34333b2a7e45fc05ab8d85be251e7409bd9035d60e3e7f10%2FMashable_Web.png&source=lower+footer+contact+link
# http://jobs.mashable.com
# https://mashable.com?geo=US&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://mashable.com?geo=AU&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://me.mashable.com?geo=ME&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://sea.mashable.com?geo=SEA&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://mashable.com?geo=GB&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://twitter.com/intent/follow?region=follow_link&screen_name=mashable&tw_p=followbutton&variant=2.0
# https://twitter.com/intent/tweet?original_referer=https://mashable.com/&source=tweetbutton&text=13+Static+Site+Generators+to+Help+You+Build+Your+Ultimate+Website&url=https%3A%2F%2Fmashable.com%2F2014%2F08%2F28%2Fstatic-website-generators%2F&via=mashable
# http://jekyllrb.com/
# http://octopress.org/
# http://docpad.org/
# http://hugo.spf13.com/
# http://wintersmith.io/
# http://middlemanapp.com/
# http://nanoc.ws/
# http://www.metalsmith.io/
# http://hexo.io/index.html
# http://harpjs.com/
# https://github.com/koenbok/Cactus/
# http://blog.getpelican.com/
# https://sculpin.io/
# http://jobs.mashable.com
# https://t.yesware.com/tt/71b30593224daffd090ea9e6e9a481b97a93a23e/6192469e5a936fed0f85e635cbb1d635/d7b076cb4f776b359888a0adc1e8ea67/support.stackcommerce.com/hc/en-us/requests/new?persona=Internet+Culture&publisher_id=273&publisher_logo=https%3A%2F%2Fcdnp1.stackassets.com%2Ffe11f98bd7119dad30cf34c37f61e214dc6e61c3%2Fstore%2Ff21e674c706b34333b2a7e45fc05ab8d85be251e7409bd9035d60e3e7f10%2FMashable_Web.png&source=lower+footer+contact+link
# https://www.facebook.com/mashable/
# https://twitter.com/mashable
# http://feeds.mashable.com/Mashable
# https://pinterest.com/mashable/
# https://www.youtube.com/user/mashable
# https://www.stumbleupon.com/channel/Mashable
# https://www.linkedin.com/company/mashable

# %% [markdown]
# We can write above code in simple way, this code will also give the only links which are started with both "https" and "http" in "a" tag.

# %%
for link in soup.findAll('a', attrs = {"href" : re.compile("^http")}):
    print(link['href'])
# Out:
# https://twitter.com/mashable
# https://www.pinterest.com/Mashable/
# http://feeds.mashable.com/Mashable
# https://t.yesware.com/tt/71b30593224daffd090ea9e6e9a481b97a93a23e/6192469e5a936fed0f85e635cbb1d635/d7b076cb4f776b359888a0adc1e8ea67/support.stackcommerce.com/hc/en-us/requests/new?persona=Internet+Culture&publisher_id=273&publisher_logo=https%3A%2F%2Fcdnp1.stackassets.com%2Ffe11f98bd7119dad30cf34c37f61e214dc6e61c3%2Fstore%2Ff21e674c706b34333b2a7e45fc05ab8d85be251e7409bd9035d60e3e7f10%2FMashable_Web.png&source=lower+footer+contact+link
# http://jobs.mashable.com
# https://mashable.com?geo=US&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://mashable.com?geo=AU&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://me.mashable.com?geo=ME&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://sea.mashable.com?geo=SEA&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://mashable.com?geo=GB&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://twitter.com/intent/follow?region=follow_link&screen_name=mashable&tw_p=followbutton&variant=2.0
# https://twitter.com/intent/tweet?original_referer=https://mashable.com/&source=tweetbutton&text=13+Static+Site+Generators+to+Help+You+Build+Your+Ultimate+Website&url=https%3A%2F%2Fmashable.com%2F2014%2F08%2F28%2Fstatic-website-generators%2F&via=mashable
# http://jekyllrb.com/
# http://octopress.org/
# http://docpad.org/
# http://hugo.spf13.com/
# http://wintersmith.io/
# http://middlemanapp.com/
# http://nanoc.ws/
# http://www.metalsmith.io/
# http://hexo.io/index.html
# http://harpjs.com/
# https://github.com/koenbok/Cactus/
# http://blog.getpelican.com/
# https://sculpin.io/
# http://jobs.mashable.com
# https://t.yesware.com/tt/71b30593224daffd090ea9e6e9a481b97a93a23e/6192469e5a936fed0f85e635cbb1d635/d7b076cb4f776b359888a0adc1e8ea67/support.stackcommerce.com/hc/en-us/requests/new?persona=Internet+Culture&publisher_id=273&publisher_logo=https%3A%2F%2Fcdnp1.stackassets.com%2Ffe11f98bd7119dad30cf34c37f61e214dc6e61c3%2Fstore%2Ff21e674c706b34333b2a7e45fc05ab8d85be251e7409bd9035d60e3e7f10%2FMashable_Web.png&source=lower+footer+contact+link
# https://www.facebook.com/mashable/
# https://twitter.com/mashable
# http://feeds.mashable.com/Mashable
# https://pinterest.com/mashable/
# https://www.youtube.com/user/mashable
# https://www.stumbleupon.com/channel/Mashable
# https://www.linkedin.com/company/mashable

# %% [markdown]
# This code will give the all the values of "href" attributes which are in "a" tag, in this output we can see some are not links then also we have got as output because we are extracting all href attribute values.

# %%
for link in soup.findAll('a', href=True):
    print(link['href'])
# Out:
# /cookie-policy/
# #
# /
# /videos/
# /entertainment/
# /category/movies/
# /category/gaming/
# /category/television/
# /culture/
# /category/web-culture/
# /category/sex/
# /category/celebrities/
# /category/memes/
# /category/parenting/
# /category/social-media/
# /tech/
# /business/
# /category/apps/
# /category/gadgets/
# /category/reviews/
# /category/mobile/
# /category/smart-home/
# /category/how-to/
# /category/mashable-choice/
# /science/
# /category/climate/
# /category/space/
# /social-good/
# /category/lgbtq/
# /category/feminism/
# /category/gender-equality/
# /category/activism/
# /category/charity/
# /category/mashable-shopping
# /category/tech
# /category/vpn/
# /category/headphones/
# /category/speakers/
# /category/laptops/
# /category/web-hosting/
# /category/antivirus/
# /category/lifestyle
# /category/home/
# /category/kitchen/
# /category/gift-guide/
# /category/gaming/
# /category/culture
# /category/dating/
# /category/pets/
# /category/subscription-boxes/
# /category/tech
# /2018/05/23/best-vpns-on-reddit-pia-purevpn-expressvpn
# /2018/05/31/best-cheap-vpn-services
# /roundup/best-tv-streaming-services-directv-hulu-sling
# /roundup/best-cheap-laptops-under-500
# /roundup/best-headphones-for-running
# /roundup/best-bluetooth-speakers
# /category/culture
# /roundup/best-dating-sites
# /roundup/best-free-dating-sites-apps-hinge-tinder-okcupid
# /roundup/best-dating-sites-for-introverts
# /roundup/which-dna-test-is-best-ancestry-23-and-me
# /roundup/best-dog-dna-tests
# /roundup/best-subscription-boxes
# /category/lifestyle
# /roundup/best-air-fryers
# /roundup/best-cordless-vacuums
# /2018/01/24/best-instant-pot-to-buy-recipes-deals-amazon
# /gifts/best-gifts-under-50-dollars
# /roundup/best-robot-vacuums
# /roundup/best-vacuums-for-pet-hair
# /login/
# /follow-mashable/
# https://twitter.com/mashable
# https://www.pinterest.com/Mashable/
# http://feeds.mashable.com/Mashable
# /subscriptions/
# /follow-mashable
# /search/
# #
# /videos/
# /entertainment/
# /culture/
# /tech/
# /science/
# /social-good/
# /about/
# mailto:brand_licensing@ziffdavis.com?subject=Mashable%20Licensing%20Inquiry
# /2019/
# /careers/
# /contact-us/
# /submit/
# https://t.yesware.com/tt/71b30593224daffd090ea9e6e9a481b97a93a23e/6192469e5a936fed0f85e635cbb1d635/d7b076cb4f776b359888a0adc1e8ea67/support.stackcommerce.com/hc/en-us/requests/new?persona=Internet+Culture&publisher_id=273&publisher_logo=https%3A%2F%2Fcdnp1.stackassets.com%2Ffe11f98bd7119dad30cf34c37f61e214dc6e61c3%2Fstore%2Ff21e674c706b34333b2a7e45fc05ab8d85be251e7409bd9035d60e3e7f10%2FMashable_Web.png&source=lower+footer+contact+link
# /advertise/
# javascript:window.zdconsent.showConsentTool()
# /privacy/
# /terms/
# /cookie-policy/
# /accessibility-statement/
# /category/travel/
# /category/security/
# /category/how-to/
# /category/mashable-shopping/
# /category/gift-guides/
# http://jobs.mashable.com
# /sgs/
# https://mashable.com?geo=US&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://mashable.com?geo=AU&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://me.mashable.com?geo=ME&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://sea.mashable.com?geo=SEA&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://mashable.com?geo=GB&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://twitter.com/intent/follow?region=follow_link&screen_name=mashable&tw_p=followbutton&variant=2.0
# #
# https://twitter.com/intent/tweet?original_referer=https://mashable.com/&source=tweetbutton&text=13+Static+Site+Generators+to+Help+You+Build+Your+Ultimate+Website&url=https%3A%2F%2Fmashable.com%2F2014%2F08%2F28%2Fstatic-website-generators%2F&via=mashable
# #
# #
# #
# /author/grace-smith/
# http://jekyllrb.com/
# http://octopress.org/
# http://docpad.org/
# http://hugo.spf13.com/
# http://wintersmith.io/
# http://middlemanapp.com/
# http://nanoc.ws/
# http://www.metalsmith.io/
# http://hexo.io/index.html
# http://harpjs.com/
# https://github.com/koenbok/Cactus/
# http://blog.getpelican.com/
# https://sculpin.io/
# /category/apps-software/
# /category/dev-design/
# /category/node.js
# /category/python/
# /category/ruby/
# /category/static-website/
# /category/tech/
# /category/website-creation/
# /about/
# http://jobs.mashable.com
# /advertise/
# /2011/05/09/connect-with-mashable/
# https://t.yesware.com/tt/71b30593224daffd090ea9e6e9a481b97a93a23e/6192469e5a936fed0f85e635cbb1d635/d7b076cb4f776b359888a0adc1e8ea67/support.stackcommerce.com/hc/en-us/requests/new?persona=Internet+Culture&publisher_id=273&publisher_logo=https%3A%2F%2Fcdnp1.stackassets.com%2Ffe11f98bd7119dad30cf34c37f61e214dc6e61c3%2Fstore%2Ff21e674c706b34333b2a7e45fc05ab8d85be251e7409bd9035d60e3e7f10%2FMashable_Web.png&source=lower+footer+contact+link
# /privacy/
# /terms/
# https://www.facebook.com/mashable/
# https://twitter.com/mashable
# http://feeds.mashable.com/Mashable
# https://pinterest.com/mashable/
# https://www.youtube.com/user/mashable
# https://www.stumbleupon.com/channel/Mashable
# https://www.linkedin.com/company/mashable
# /

# %% [markdown]
# https://mashable.com/2014/08/28/static-website-generators/privacy
# https://mashable.com/2014/08/28/static-website-generators/terms
# https://www.facebook.com/mashable/
# https://twitter.com/mashable
# http://feeds.mashable.com/Mashable
# https://pinterest.com/mashable/
# https://www.youtube.com/user/mashable
# https://www.stumbleupon.com/channel/Mashable
# https://www.linkedin.com/company/mashable
# https://mashable.com/2014/08/28/static-website-generators/

# %% [markdown]
# Here we are extracting the links from two tags ("a", "link") by passing them as list, where the attribute ("href") value is started with "http" (includes "http" and "https").

# %%
for link in soup.find_all(["a", "link"], attrs = {'href': re.compile("^http")}):
    print(link['href'])
# Out:
# https://a.amz.mshcdn.com/assets/app-aa9e2819d9ee8b5b94ae6795fa28af98c57ab83d542ee99b54975db7e9055eda.css
# https://a.amz.mshcdn.com/assets/csshake-08f0628738d4674eeeeec2337d9c0c85450194c2de5747e07c21371e25a54c18.css
# https://a.amz.mshcdn.com/assets/posts-cf2686c4a4777816be86f958f31179b7356b3d72ec7f061e4785b5e5f4466f07.css
# http://feeds.mashable.com/Mashable
# https://mashable.com/apple-touch-icon-57x57.png?v=m2Pmw8zNwl
# https://mashable.com/apple-touch-icon-60x60.png?v=m2Pmw8zNwl
# https://mashable.com/apple-touch-icon-72x72.png?v=m2Pmw8zNwl
# https://mashable.com/apple-touch-icon-76x76.png?v=m2Pmw8zNwl
# https://mashable.com/apple-touch-icon-114x114.png?v=m2Pmw8zNwl
# https://mashable.com/apple-touch-icon-120x120.png?v=m2Pmw8zNwl
# https://mashable.com/apple-touch-icon-144x144.png?v=m2Pmw8zNwl
# https://mashable.com/apple-touch-icon-152x152.png?v=m2Pmw8zNwl
# https://mashable.com/apple-touch-icon-180x180.png?v=m2Pmw8zNwl
# https://mashable.com/favicon-32x32.png?v=m2Pmw8zNwl
# https://mashable.com/android-chrome-192x192.png?v=m2Pmw8zNwl
# https://mashable.com/favicon-96x96.png?v=m2Pmw8zNwl
# https://mashable.com/favicon-16x16.png?v=m2Pmw8zNwl
# https://mashable.com/manifest.json?v=m2Pmw8zNwl
# https://mashable.com/favicon.ico?v=m2Pmw8zNwl
# https://a.amz.mshcdn.com/assets/mashable.touchicon-85568436777b97f88ef7182140a53fd1a4f7cec7c0fa5568a3783fcdb0d08eb5.png
# https://mashable.com/2014/08/28/static-website-generators/
# https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F1200x627.jpg?signature=yBUh5zWmwdXaL9bW9zdjsIMzFc4=
# https://twitter.com/mashable
# https://www.pinterest.com/Mashable/
# http://feeds.mashable.com/Mashable
# https://t.yesware.com/tt/71b30593224daffd090ea9e6e9a481b97a93a23e/6192469e5a936fed0f85e635cbb1d635/d7b076cb4f776b359888a0adc1e8ea67/support.stackcommerce.com/hc/en-us/requests/new?persona=Internet+Culture&publisher_id=273&publisher_logo=https%3A%2F%2Fcdnp1.stackassets.com%2Ffe11f98bd7119dad30cf34c37f61e214dc6e61c3%2Fstore%2Ff21e674c706b34333b2a7e45fc05ab8d85be251e7409bd9035d60e3e7f10%2FMashable_Web.png&source=lower+footer+contact+link
# http://jobs.mashable.com
# https://mashable.com?geo=US&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://mashable.com?geo=AU&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://me.mashable.com?geo=ME&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://sea.mashable.com?geo=SEA&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://mashable.com?geo=GB&utm_campaign=mash-prod-nav-geo&utm_source=internal&utm_medium=onsite
# https://twitter.com/intent/follow?region=follow_link&screen_name=mashable&tw_p=followbutton&variant=2.0
# https://twitter.com/intent/tweet?original_referer=https://mashable.com/&source=tweetbutton&text=13+Static+Site+Generators+to+Help+You+Build+Your+Ultimate+Website&url=https%3A%2F%2Fmashable.com%2F2014%2F08%2F28%2Fstatic-website-generators%2F&via=mashable
# http://jekyllrb.com/
# http://octopress.org/
# http://docpad.org/
# http://hugo.spf13.com/
# http://wintersmith.io/
# http://middlemanapp.com/
# http://nanoc.ws/
# http://www.metalsmith.io/
# http://hexo.io/index.html
# http://harpjs.com/
# https://github.com/koenbok/Cactus/
# http://blog.getpelican.com/
# https://sculpin.io/
# http://jobs.mashable.com
# https://t.yesware.com/tt/71b30593224daffd090ea9e6e9a481b97a93a23e/6192469e5a936fed0f85e635cbb1d635/d7b076cb4f776b359888a0adc1e8ea67/support.stackcommerce.com/hc/en-us/requests/new?persona=Internet+Culture&publisher_id=273&publisher_logo=https%3A%2F%2Fcdnp1.stackassets.com%2Ffe11f98bd7119dad30cf34c37f61e214dc6e61c3%2Fstore%2Ff21e674c706b34333b2a7e45fc05ab8d85be251e7409bd9035d60e3e7f10%2FMashable_Web.png&source=lower+footer+contact+link
# https://www.facebook.com/mashable/
# https://twitter.com/mashable
# http://feeds.mashable.com/Mashable
# https://pinterest.com/mashable/
# https://www.youtube.com/user/mashable
# https://www.stumbleupon.com/channel/Mashable
# https://www.linkedin.com/company/mashable

# %% [markdown]
# Here we are extracting all image links using "src" attribute.

# %%
for img in soup.findAll('img'):
    print(img.get('src'))
# Out:
# https://zdbb.net/l/z0WVjCBSEeGLoxIxOQVEwQ
# https://a.amz.mshcdn.com/assets/header_logo.v2.in-4d5f1a092c48e9233425f15c44f25a7c0cbed1bedbd8335160519124df085d70.png
# https://a.amz.mshcdn.com/assets/header_logo.v2.in.dark-6b9cbc5f71f93f6822d795def6fd049efa1fd58bd0ec75e1b05a734c28972a35.png
# https://mondrian.mashable.com/2014%252F08%252F28%252F3f%252FComputer_Ge.0260d.jpg%252F950x534__filters%253Aquality%252880%2529.jpg?signature=0xumFqCna6GGL1UL2y55zX77tpY=
# https://mondrian.mashable.com/wp-content%252Fgallery%252Fstatic-website-generators%252F1-jekyll.jpg%252Ffit-in__850x850.jpg?signature=vHTPPaBBHwj1o8BZosu6B5KHyy0=&source=https%3A%2F%2Fmashable.com
