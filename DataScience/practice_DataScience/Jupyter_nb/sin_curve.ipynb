# %% [markdown]
# ### For %run command

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 4 * np.pi, 0.1)   
y = np.sin(x)

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### For %store command

# %%
#retrieve string passed from another notebook
# %store -r string
print(string)
# Out:
# no stored variable or alias string
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23416/2347411175.py in <module>
#       1 #retrieve string passed from another notebook
#       2 get_ipython().run_line_magic('store', '-r string')
# ----> 3 print(string)
#
# NameError: name 'string' is not defined
